# %% [markdown]
# <a href="https://colab.research.google.com/github/shilvi53/BigDataAnalysis/blob/main/Assignment7_15april_202301058.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
X = np.array([1 ,2, 3, 4, 5, 6, 7]).reshape(-1, 1)
y = np.array([9 ,8, 10, 12, 11, 13, 14])
model = LinearRegression()
model.fit(X, y)
y_pred = model.predict(X)
plt.scatter(X, y,color='red')
plt.plot(X, y_pred,color='blue')
plt.xlabel('X')
plt.ylabel('y')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
X = np.array([1 ,2, 3, 4, 5, 6, 7])
y = np.array([9 ,8, 10, 12, 11, 13, 14])
mean_X = np.mean(X)
mean_y = np.mean(y)
beta1 = np.sum((X - mean_X) * (y - mean_y)) / np.sum((X - mean_X)**2)
beta0 = mean_y - beta1 * mean_X
y_pred = beta0 + beta1 * X
plt.scatter(X, y, color='blue')
plt.plot(X, y_pred, color='red')
plt.xlabel('X')
plt.ylabel('y')
plt.show()

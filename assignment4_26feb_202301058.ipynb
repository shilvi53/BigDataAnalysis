# %% [markdown]
# <a href="https://colab.research.google.com/github/shilvi53/BigDataAnalysis/blob/main/assignment4_26feb_202301058.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv("company_sales_data.csv")

plt.plot(data['month_number'], data['total_profit'])

plt.title("line plot")

plt.xlabel('Day')
plt.ylabel('Tip')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv("company_sales_data.csv")

plt.plot(data['month_number'], data['facecream'])
plt.plot(data['month_number'], data['facewash'])
plt.plot(data['month_number'], data['toothpaste'])
plt.plot(data['month_number'], data['bathingsoap'])
plt.plot(data['month_number'], data['shampoo'])
plt.plot(data['month_number'], data['moisturizer'])
# plt.plot()

plt.title("line plot")

plt.xlabel('Day')
plt.ylabel('Tip')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv("company_sales_data.csv")

plt.bar(data['month_number'], data['total_units'])

# plt.plot()

plt.title("line plot")

plt.xlabel('Day')
plt.ylabel('Tip')
plt.show()

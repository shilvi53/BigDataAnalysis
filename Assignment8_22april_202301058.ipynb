# %% [markdown]
# <a href="https://colab.research.google.com/github/shilvi53/BigDataAnalysis/blob/main/Assignment8_22april_202301058.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.linear_model import LinearRegression
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data = {
    'X1': [60, 62, 67, 70, 71,72,75,78],
    'X2': [22, 25, 24, 20, 15,14,14,11],
    'Y': [140, 155, 159, 179, 192,200,212,215]
}
df = pd.DataFrame(data)
X = df[['X1', 'X2']]
Y = df['Y']
model = LinearRegression().fit(X, Y)
predicted_Y = model.predict(X)
plt.scatter(Y, predicted_Y)
plt.xlabel('Actual Y')
plt.ylabel('Predicted Y')
plt.show()
